# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/scmisa/SCI_SC2_LatentTrainer/blob/main/colab_setup.ipynb)

# %% [markdown]
# ## 1. Check GPU Availability

# %%
# Check GPU availability
# !nvidia-smi
# Out:
# Sun Oct 19 21:24:16 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## 2. Clone Repository

# %%
# Clone the repository from GitHub
import os
import shutil

repo_url = "https://github.com/scmisa/SCI_SC2_LatentTrainer.git"
repo_name = "SCI_SC2_LatentTrainer"

# Check if repository already exists
if os.path.exists(repo_name):
    print(f"Repository '{repo_name}' already exists. Removing it...")
    shutil.rmtree(repo_name)

# Clone the repository
print(f"Cloning repository from {repo_url}...")
# !git clone {repo_url}

# Change to repository directory
# %cd {repo_name}
print(f"Successfully cloned and entered {repo_name} directory!")
# Out:
# Cloning repository from https://github.com/scmisa/SCI_SC2_LatentTrainer.git...
# Cloning into 'SCI_SC2_LatentTrainer'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'SCI_SC2_LatentTrainer'
# /content
# Successfully cloned and entered SCI_SC2_LatentTrainer directory!

# %% [markdown]
# ## 3. Install Dependencies

# %%
# Install uv package manager
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"/root/.local/bin:{os.environ['PATH']}"
# !uv --version

# %%
# Install dependencies with PyTorch CUDA support
import os
os.environ['UV_EXTRA_INDEX_URL'] = 'https://download.pytorch.org/whl/cu121'
# !uv pip install --system -e .

# %% [markdown]
# ## 4. Verify Installation

# %%
# Verify PyTorch CUDA installation
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

# %% [markdown]
# ## 5. Setup Directories

# %%
# Create necessary directories
# !mkdir -p output/tensorboard_logs output/checkpoints output/predictions
# !mkdir -p data/download data/unpack
# !ls -la

# %% [markdown]
# ## 6. Optional: Mount Google Drive
#
# Mount Google Drive to save your models and data across sessions:

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create directory in Drive if it doesn't exist
# !mkdir -p /content/drive/MyDrive/SC2_LatentTrainer_Output

# Use Drive for outputs (comment out if you don't want to use Drive)
# !rm -rf output
# !ln -s /content/drive/MyDrive/SC2_LatentTrainer_Output output

# %% [markdown]
# ## 7. Start TensorBoard

# %%
# Load TensorBoard extension and start it
# %load_ext tensorboard
# %tensorboard --logdir output/tensorboard_logs --port 6006

# %% [markdown]
# ## 8. Run Training
#
# Now you can run your training script. Adjust the command based on your needs:

# %%
# Example: Run training with default config
# Adjust this command based on your actual training script
# !python -m latent_trainer.train --config config/train.yaml

# Or if you have a different entry point:
# !python src/main.py --epochs 100 --batch-size 32

# %% [markdown]
# ## 9. Monitor Training
#
# You can monitor training progress in TensorBoard above, or check logs:

# %%
# Monitor training progress
# TensorBoard is already running above, you can also check:

# View recent training output
# !ls -lh output/checkpoints/

# Check if training process is running
# !ps aux | grep python

# Or view logs if your training script creates them
# !cat output/training.log

# %% [markdown]
# ## 10. Download Trained Models
#
# After training completes, download your models:

# %%
# Zip and download checkpoints
# !zip -r checkpoints.zip output/checkpoints/
from google.colab import files
files.download('checkpoints.zip')

# %% [markdown]
# ## Tips for Using Colab:
#
# - **GPU Runtime**: ~12-15 hours per day (free tier)
# - **Session timeout**: 90 minutes idle, 12 hours max
# - **Save frequently**: Use Google Drive mount to persist data
# - **Checkpointing**: Enable model checkpointing to resume training
# - **Colab Pro**: $9.99/month for longer runtimes and better GPUs
